# %% [markdown]
# ECE 5460, Au23
#
# Solution for PyTorch Tutorial - final model only

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

ds = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

# spliting training into train and validation
generator = torch.Generator().manual_seed(24)
(trainset, valset) = torch.utils.data.random_split(ds, [0.8, 0.2], generator=generator)


trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                          shuffle=False, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# We will use a convolutional network for classification.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 80)
        self.fc2 = nn.Linear(80, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net()

# %% [markdown]
# Define a loss function and optimizer

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001) #Experiment with momentum term and other learning rates

# %% [markdown]
# Define training function

# %%
def train_step(model, inputs, labels):
  # zero the parameter gradients
  optimizer.zero_grad()

  # forward call
  outputs = model(inputs)

  # calculate loss
  loss = criterion(outputs, labels)

  # back propagation and optimization
  loss.backward()
  optimizer.step()

  return loss

# %% [markdown]
# Define evaluation function
#
# Same can be used for testing

# %%
def val_step(model, inputs, labels):
  # get inputs and labels from given batch
  with torch.no_grad():
    outputs = model(inputs)

    # calculate the predicted class
    _, predicted = torch.max(outputs.data, 1)
    loss = criterion(outputs, labels)
    correct_pred = (predicted == labels).sum().item() # correctly classified samples of the current batch
  return correct_pred, loss

# %% [markdown]
# Main training and validation

# %%
import time
num_epochs = 50 # change this to a larger number to train the final network


device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print("using device: ", device)


model = model.to(device)

val_acc_log = []
val_loss_log = []

for i in range(num_epochs):
  running_loss = 0
  for j, batch in enumerate(trainloader):
    inputs, labels = batch
    inputs = inputs.to(device)
    labels = labels.to(device)

    # training step
    loss = train_step(model, inputs, labels)
    running_loss += loss.item()

    # print some statistics
    if (j+1) % 1000 == 0 :
      print("epoch {}, step = {}, running loss = {:.4f}".format(i, str(j+1).zfill(5), running_loss / 1000))
      running_loss = 0



  # validation at the end of each epoch
  total_correct_pred = 0
  val_loss = []
  for _, batch in enumerate(valloader):
    inputs, labels = batch
    inputs = inputs.to(device)
    labels = labels.to(device)

    curr_correct_pred, curr_loss = val_step(model, inputs, labels)

    # keep track of corrected samples and loss
    total_correct_pred += curr_correct_pred
    val_loss.append(curr_loss.item())

  val_loss = torch.Tensor(val_loss).mean()
  acc = total_correct_pred / len(valset)
  print("val accuracy: {:.2f}, avg loss = {:.3f}".format(100*acc, val_loss))
  val_acc_log.append(acc * 100)
  val_loss_log.append(val_loss.item())

  # save the checkpoint
  torch.save({
            'epoch': i,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, 'epoch_{}_val_acc_{}.pt'.format(i, 100*acc))
# Out:
# using device:  cuda:0
# epoch 0, step = 01000, running loss = 2.3021
# epoch 0, step = 02000, running loss = 2.2958
# epoch 0, step = 03000, running loss = 2.2863
# epoch 0, step = 04000, running loss = 2.2621
# epoch 0, step = 05000, running loss = 2.2042
# epoch 0, step = 06000, running loss = 2.1492
# epoch 0, step = 07000, running loss = 2.0899
# epoch 0, step = 08000, running loss = 2.0751
# epoch 0, step = 09000, running loss = 2.0364
# epoch 0, step = 10000, running loss = 1.9918
# val accuracy: 28.16, avg loss = 1.991
# epoch 1, step = 01000, running loss = 1.9878
# epoch 1, step = 02000, running loss = 1.9158
# epoch 1, step = 03000, running loss = 1.9269
# epoch 1, step = 04000, running loss = 1.8802
# epoch 1, step = 05000, running loss = 1.8492
# epoch 1, step = 06000, running loss = 1.8257
# epoch 1, step = 07000, running loss = 1.7782
# epoch 1, step = 08000, running loss = 1.7604
# epoch 1, step = 09000, running loss = 1.7374
# epoch 1, step = 10000, running loss = 1.7115
# val accuracy: 37.41, avg loss = 1.712
# epoch 2, step = 01000, running loss = 1.6773
# epoch 2, step = 02000, running loss = 1.7043
# epoch 2, step = 03000, running loss = 1.6672
# epoch 2, step = 04000, running loss = 1.6495
# epoch 2, step = 05000, running loss = 1.6335
# epoch 2, step = 06000, running loss = 1.6593
# epoch 2, step = 07000, running loss = 1.6171
# epoch 2, step = 08000, running loss = 1.6017
# epoch 2, step = 09000, running loss = 1.5740
# epoch 2, step = 10000, running loss = 1.5693
# val accuracy: 43.93, avg loss = 1.558
# epoch 3, step = 01000, running loss = 1.5516
# epoch 3, step = 02000, running loss = 1.5437
# epoch 3, step = 03000, running loss = 1.5375
# epoch 3, step = 04000, running loss = 1.5502
# epoch 3, step = 05000, running loss = 1.5209
# epoch 3, step = 06000, running loss = 1.5385
# epoch 3, step = 07000, running loss = 1.5136
# epoch 3, step = 08000, running loss = 1.5064
# epoch 3, step = 09000, running loss = 1.5031
# epoch 3, step = 10000, running loss = 1.4830
# val accuracy: 46.58, avg loss = 1.478
# epoch 4, step = 01000, running loss = 1.4813
# epoch 4, step = 02000, running loss = 1.4468
# epoch 4, step = 03000, running loss = 1.4440
# epoch 4, step = 04000, running loss = 1.4452
# epoch 4, step = 05000, running loss = 1.4538
# epoch 4, step = 06000, running loss = 1.4716
# epoch 4, step = 07000, running loss = 1.4447
# epoch 4, step = 08000, running loss = 1.4373
# epoch 4, step = 09000, running loss = 1.4261
# epoch 4, step = 10000, running loss = 1.4066
# val accuracy: 48.64, avg loss = 1.428
# epoch 5, step = 01000, running loss = 1.4143
# epoch 5, step = 02000, running loss = 1.3837
# epoch 5, step = 03000, running loss = 1.4078
# epoch 5, step = 04000, running loss = 1.3789
# epoch 5, step = 05000, running loss = 1.4037
# epoch 5, step = 06000, running loss = 1.3632
# epoch 5, step = 07000, running loss = 1.3516
# epoch 5, step = 08000, running loss = 1.3785
# epoch 5, step = 09000, running loss = 1.3625
# epoch 5, step = 10000, running loss = 1.3489
# val accuracy: 50.50, avg loss = 1.374
# epoch 6, step = 01000, running loss = 1.3247
# epoch 6, step = 02000, running loss = 1.3695
# epoch 6, step = 03000, running loss = 1.3237
# epoch 6, step = 04000, running loss = 1.3300
# epoch 6, step = 05000, running loss = 1.3096
# epoch 6, step = 06000, running loss = 1.3069
# epoch 6, step = 07000, running loss = 1.3244
# epoch 6, step = 08000, running loss = 1.3196
# epoch 6, step = 09000, running loss = 1.3129
# epoch 6, step = 10000, running loss = 1.3374
# val accuracy: 52.70, avg loss = 1.314
# epoch 7, step = 01000, running loss = 1.2753
# epoch 7, step = 02000, running loss = 1.3029
# epoch 7, step = 03000, running loss = 1.2617
# epoch 7, step = 04000, running loss = 1.2856
# epoch 7, step = 05000, running loss = 1.3014
# epoch 7, step = 06000, running loss = 1.2891
# epoch 7, step = 07000, running loss = 1.3129
# epoch 7, step = 08000, running loss = 1.2542
# epoch 7, step = 09000, running loss = 1.2438
# epoch 7, step = 10000, running loss = 1.2821
# val accuracy: 53.46, avg loss = 1.296
# epoch 8, step = 01000, running loss = 1.2699
# epoch 8, step = 02000, running loss = 1.2757
# epoch 8, step = 03000, running loss = 1.2412
# epoch 8, step = 04000, running loss = 1.2380
# epoch 8, step = 05000, running loss = 1.2611
# epoch 8, step = 06000, running loss = 1.2260
# epoch 8, step = 07000, running loss = 1.2270
# epoch 8, step = 08000, running loss = 1.2498
# epoch 8, step = 09000, running loss = 1.2262
# epoch 8, step = 10000, running loss = 1.2179
# val accuracy: 56.01, avg loss = 1.260
# epoch 9, step = 01000, running loss = 1.2270
# epoch 9, step = 02000, running loss = 1.2089
# epoch 9, step = 03000, running loss = 1.2046
# epoch 9, step = 04000, running loss = 1.2165
# epoch 9, step = 05000, running loss = 1.2289
# epoch 9, step = 06000, running loss = 1.1915
# epoch 9, step = 07000, running loss = 1.2125
# epoch 9, step = 08000, running loss = 1.1964
# epoch 9, step = 09000, running loss = 1.1982
# epoch 9, step = 10000, running loss = 1.1948
# val accuracy: 54.93, avg loss = 1.264
# epoch 10, step = 01000, running loss = 1.1845
# epoch 10, step = 02000, running loss = 1.1687
# epoch 10, step = 03000, running loss = 1.1696
# epoch 10, step = 04000, running loss = 1.1689
# epoch 10, step = 05000, running loss = 1.1953
# epoch 10, step = 06000, running loss = 1.1710
# epoch 10, step = 07000, running loss = 1.1762
# epoch 10, step = 08000, running loss = 1.1935
# epoch 10, step = 09000, running loss = 1.1744
# epoch 10, step = 10000, running loss = 1.1485
# val accuracy: 56.21, avg loss = 1.229
# epoch 11, step = 01000, running loss = 1.1865
# epoch 11, step = 02000, running loss = 1.1339
# epoch 11, step = 03000, running loss = 1.1465
# epoch 11, step = 04000, running loss = 1.1214
# epoch 11, step = 05000, running loss = 1.1383
# epoch 11, step = 06000, running loss = 1.1381
# epoch 11, step = 07000, running loss = 1.1505
# epoch 11, step = 08000, running loss = 1.1586
# epoch 11, step = 09000, running loss = 1.1669
# epoch 11, step = 10000, running loss = 1.1393
# val accuracy: 58.26, avg loss = 1.186
# epoch 12, step = 01000, running loss = 1.1314
# epoch 12, step = 02000, running loss = 1.1286
# epoch 12, step = 03000, running loss = 1.1363
# epoch 12, step = 04000, running loss = 1.1174
# epoch 12, step = 05000, running loss = 1.1204
# epoch 12, step = 06000, running loss = 1.1247
# epoch 12, step = 07000, running loss = 1.1218
# epoch 12, step = 08000, running loss = 1.1218
# epoch 12, step = 09000, running loss = 1.0949
# epoch 12, step = 10000, running loss = 1.1144
# val accuracy: 59.14, avg loss = 1.165
# epoch 13, step = 01000, running loss = 1.0940
# epoch 13, step = 02000, running loss = 1.0965
# epoch 13, step = 03000, running loss = 1.1082
# epoch 13, step = 04000, running loss = 1.0967
# epoch 13, step = 05000, running loss = 1.0964
# epoch 13, step = 06000, running loss = 1.0847
# epoch 13, step = 07000, running loss = 1.0800
# epoch 13, step = 08000, running loss = 1.0946
# epoch 13, step = 09000, running loss = 1.1282
# epoch 13, step = 10000, running loss = 1.0793
# val accuracy: 59.27, avg loss = 1.164
# epoch 14, step = 01000, running loss = 1.0656
# epoch 14, step = 02000, running loss = 1.0903
# epoch 14, step = 03000, running loss = 1.0705
# epoch 14, step = 04000, running loss = 1.0805
# epoch 14, step = 05000, running loss = 1.0793
# epoch 14, step = 06000, running loss = 1.0693
# epoch 14, step = 07000, running loss = 1.0680
# epoch 14, step = 08000, running loss = 1.0745
# epoch 14, step = 09000, running loss = 1.0936
# epoch 14, step = 10000, running loss = 1.0633
# val accuracy: 60.06, avg loss = 1.138
# epoch 15, step = 01000, running loss = 1.0571
# epoch 15, step = 02000, running loss = 1.0359
# epoch 15, step = 03000, running loss = 1.0521
# epoch 15, step = 04000, running loss = 1.0802
# epoch 15, step = 05000, running loss = 1.0565
# epoch 15, step = 06000, running loss = 1.0259
# epoch 15, step = 07000, running loss = 1.0626
# epoch 15, step = 08000, running loss = 1.0952
# epoch 15, step = 09000, running loss = 1.0199
# epoch 15, step = 10000, running loss = 1.0554
# val accuracy: 60.70, avg loss = 1.129
# epoch 16, step = 01000, running loss = 1.0271
# epoch 16, step = 02000, running loss = 1.0221
# epoch 16, step = 03000, running loss = 1.0619
# epoch 16, step = 04000, running loss = 1.0699
# epoch 16, step = 05000, running loss = 1.0041
# epoch 16, step = 06000, running loss = 1.0342
# epoch 16, step = 07000, running loss = 1.0478
# epoch 16, step = 08000, running loss = 1.0257
# epoch 16, step = 09000, running loss = 1.0401
# epoch 16, step = 10000, running loss = 1.0230
# val accuracy: 60.86, avg loss = 1.119
# epoch 17, step = 01000, running loss = 0.9938
# epoch 17, step = 02000, running loss = 1.0398
# epoch 17, step = 03000, running loss = 1.0059
# epoch 17, step = 04000, running loss = 1.0166
# epoch 17, step = 05000, running loss = 1.0239
# epoch 17, step = 06000, running loss = 0.9987
# epoch 17, step = 07000, running loss = 1.0135
# epoch 17, step = 08000, running loss = 1.0342
# epoch 17, step = 09000, running loss = 1.0191
# epoch 17, step = 10000, running loss = 1.0172
# val accuracy: 60.75, avg loss = 1.118
# epoch 18, step = 01000, running loss = 0.9867
# epoch 18, step = 02000, running loss = 0.9805
# epoch 18, step = 03000, running loss = 0.9757
# epoch 18, step = 04000, running loss = 1.0168
# epoch 18, step = 05000, running loss = 1.0243
# epoch 18, step = 06000, running loss = 0.9847
# epoch 18, step = 07000, running loss = 1.0167
# epoch 18, step = 08000, running loss = 1.0240
# epoch 18, step = 09000, running loss = 1.0117
# epoch 18, step = 10000, running loss = 0.9745
# val accuracy: 59.79, avg loss = 1.162
# epoch 19, step = 01000, running loss = 0.9515
# epoch 19, step = 02000, running loss = 0.9879
# epoch 19, step = 03000, running loss = 0.9740
# epoch 19, step = 04000, running loss = 0.9524
# epoch 19, step = 05000, running loss = 0.9861
# epoch 19, step = 06000, running loss = 0.9685
# epoch 19, step = 07000, running loss = 1.0101
# epoch 19, step = 08000, running loss = 1.0112
# epoch 19, step = 09000, running loss = 0.9833
# epoch 19, step = 10000, running loss = 1.0183
# val accuracy: 60.88, avg loss = 1.120
# epoch 20, step = 01000, running loss = 0.9445
# epoch 20, step = 02000, running loss = 0.9560
# epoch 20, step = 03000, running loss = 0.9874
# epoch 20, step = 04000, running loss = 0.9753
# epoch 20, step = 05000, running loss = 0.9422
# epoch 20, step = 06000, running loss = 0.9783
# epoch 20, step = 07000, running loss = 0.9596
# epoch 20, step = 08000, running loss = 0.9928
# epoch 20, step = 09000, running loss = 0.9689
# epoch 20, step = 10000, running loss = 0.9760
# val accuracy: 61.20, avg loss = 1.107
# epoch 21, step = 01000, running loss = 0.9436
# epoch 21, step = 02000, running loss = 0.9550
# epoch 21, step = 03000, running loss = 0.9401
# epoch 21, step = 04000, running loss = 0.9349
# epoch 21, step = 05000, running loss = 0.9768
# epoch 21, step = 06000, running loss = 0.9796
# epoch 21, step = 07000, running loss = 0.9464
# epoch 21, step = 08000, running loss = 0.9473
# epoch 21, step = 09000, running loss = 0.9592
# epoch 21, step = 10000, running loss = 0.9511
# val accuracy: 62.10, avg loss = 1.090
# epoch 22, step = 01000, running loss = 0.9096
# epoch 22, step = 02000, running loss = 0.9289
# epoch 22, step = 03000, running loss = 0.9669
# epoch 22, step = 04000, running loss = 0.9463
# epoch 22, step = 05000, running loss = 0.9398
# epoch 22, step = 06000, running loss = 0.9235
# epoch 22, step = 07000, running loss = 0.9450
# epoch 22, step = 08000, running loss = 0.9475
# epoch 22, step = 09000, running loss = 0.9461
# epoch 22, step = 10000, running loss = 0.9245
# val accuracy: 61.21, avg loss = 1.111
# epoch 23, step = 01000, running loss = 0.9130
# epoch 23, step = 02000, running loss = 0.8991
# epoch 23, step = 03000, running loss = 0.9363
# epoch 23, step = 04000, running loss = 0.9434
# epoch 23, step = 05000, running loss = 0.8926
# epoch 23, step = 06000, running loss = 0.9338
# epoch 23, step = 07000, running loss = 0.9367
# epoch 23, step = 08000, running loss = 0.9355
# epoch 23, step = 09000, running loss = 0.9186
# epoch 23, step = 10000, running loss = 0.9403
# val accuracy: 61.71, avg loss = 1.102
# epoch 24, step = 01000, running loss = 0.9087
# epoch 24, step = 02000, running loss = 0.9004
# epoch 24, step = 03000, running loss = 0.8760
# epoch 24, step = 04000, running loss = 0.9158
# epoch 24, step = 05000, running loss = 0.9099
# epoch 24, step = 06000, running loss = 0.9058
# epoch 24, step = 07000, running loss = 0.9089
# epoch 24, step = 08000, running loss = 0.9189
# epoch 24, step = 09000, running loss = 0.9076
# epoch 24, step = 10000, running loss = 0.9410
# val accuracy: 60.83, avg loss = 1.115
# epoch 25, step = 01000, running loss = 0.8827
# epoch 25, step = 02000, running loss = 0.8746
# epoch 25, step = 03000, running loss = 0.9112
# epoch 25, step = 04000, running loss = 0.8655
# epoch 25, step = 05000, running loss = 0.8958
# epoch 25, step = 06000, running loss = 0.9060
# epoch 25, step = 07000, running loss = 0.8724
# epoch 25, step = 08000, running loss = 0.9187
# epoch 25, step = 09000, running loss = 0.9351
# epoch 25, step = 10000, running loss = 0.9072
# val accuracy: 61.88, avg loss = 1.087
# epoch 26, step = 01000, running loss = 0.8536
# epoch 26, step = 02000, running loss = 0.8682
# epoch 26, step = 03000, running loss = 0.8935
# epoch 26, step = 04000, running loss = 0.8824
# epoch 26, step = 05000, running loss = 0.8615
# epoch 26, step = 06000, running loss = 0.9021
# epoch 26, step = 07000, running loss = 0.8671
# epoch 26, step = 08000, running loss = 0.9086
# epoch 26, step = 09000, running loss = 0.8829
# epoch 26, step = 10000, running loss = 0.9194
# val accuracy: 61.81, avg loss = 1.106
# epoch 27, step = 01000, running loss = 0.8555
# epoch 27, step = 02000, running loss = 0.8801
# epoch 27, step = 03000, running loss = 0.9091
# epoch 27, step = 04000, running loss = 0.8608
# epoch 27, step = 05000, running loss = 0.8709
# epoch 27, step = 06000, running loss = 0.8668
# epoch 27, step = 07000, running loss = 0.8652
# epoch 27, step = 08000, running loss = 0.8771
# epoch 27, step = 09000, running loss = 0.8531
# epoch 27, step = 10000, running loss = 0.8774
# val accuracy: 62.22, avg loss = 1.091
# epoch 28, step = 01000, running loss = 0.8402
# epoch 28, step = 02000, running loss = 0.8487
# epoch 28, step = 03000, running loss = 0.8565
# epoch 28, step = 04000, running loss = 0.8351
# epoch 28, step = 05000, running loss = 0.8786
# epoch 28, step = 06000, running loss = 0.8512
# epoch 28, step = 07000, running loss = 0.8718
# epoch 28, step = 08000, running loss = 0.8783
# epoch 28, step = 09000, running loss = 0.8633
# epoch 28, step = 10000, running loss = 0.8673
# val accuracy: 62.58, avg loss = 1.090
# epoch 29, step = 01000, running loss = 0.8666
# epoch 29, step = 02000, running loss = 0.8295
# epoch 29, step = 03000, running loss = 0.8416
# epoch 29, step = 04000, running loss = 0.8158
# epoch 29, step = 05000, running loss = 0.8671
# epoch 29, step = 06000, running loss = 0.8390
# epoch 29, step = 07000, running loss = 0.8583
# epoch 29, step = 08000, running loss = 0.8312
# epoch 29, step = 09000, running loss = 0.8823
# epoch 29, step = 10000, running loss = 0.8487
# val accuracy: 62.58, avg loss = 1.079
# epoch 30, step = 01000, running loss = 0.8012
# epoch 30, step = 02000, running loss = 0.8152
# epoch 30, step = 03000, running loss = 0.8035
# epoch 30, step = 04000, running loss = 0.8814
# epoch 30, step = 05000, running loss = 0.8531
# epoch 30, step = 06000, running loss = 0.8499
# epoch 30, step = 07000, running loss = 0.8138
# epoch 30, step = 08000, running loss = 0.8384
# epoch 30, step = 09000, running loss = 0.8375
# epoch 30, step = 10000, running loss = 0.8508
# val accuracy: 62.20, avg loss = 1.092
# epoch 31, step = 01000, running loss = 0.8087
# epoch 31, step = 02000, running loss = 0.8145
# epoch 31, step = 03000, running loss = 0.8046
# epoch 31, step = 04000, running loss = 0.8063
# epoch 31, step = 05000, running loss = 0.8224
# epoch 31, step = 06000, running loss = 0.8393
# epoch 31, step = 07000, running loss = 0.8180
# epoch 31, step = 08000, running loss = 0.8412
# epoch 31, step = 09000, running loss = 0.8255
# epoch 31, step = 10000, running loss = 0.8488
# val accuracy: 62.70, avg loss = 1.079
# epoch 32, step = 01000, running loss = 0.7729
# epoch 32, step = 02000, running loss = 0.8150
# epoch 32, step = 03000, running loss = 0.8083
# epoch 32, step = 04000, running loss = 0.8109
# epoch 32, step = 05000, running loss = 0.8289
# epoch 32, step = 06000, running loss = 0.7886
# epoch 32, step = 07000, running loss = 0.8176
# epoch 32, step = 08000, running loss = 0.8238
# epoch 32, step = 09000, running loss = 0.8709
# epoch 32, step = 10000, running loss = 0.8022
# val accuracy: 61.57, avg loss = 1.115
# epoch 33, step = 01000, running loss = 0.7788
# epoch 33, step = 02000, running loss = 0.7839
# epoch 33, step = 03000, running loss = 0.7897
# epoch 33, step = 04000, running loss = 0.7764
# epoch 33, step = 05000, running loss = 0.7911
# epoch 33, step = 06000, running loss = 0.8149
# epoch 33, step = 07000, running loss = 0.8228
# epoch 33, step = 08000, running loss = 0.8146
# epoch 33, step = 09000, running loss = 0.8340
# epoch 33, step = 10000, running loss = 0.8192
# val accuracy: 62.13, avg loss = 1.101
# epoch 34, step = 01000, running loss = 0.7877
# epoch 34, step = 02000, running loss = 0.8133
# epoch 34, step = 03000, running loss = 0.7678
# epoch 34, step = 04000, running loss = 0.7868
# epoch 34, step = 05000, running loss = 0.7694
# epoch 34, step = 06000, running loss = 0.7927
# epoch 34, step = 07000, running loss = 0.7938
# epoch 34, step = 08000, running loss = 0.7750
# epoch 34, step = 09000, running loss = 0.7928
# epoch 34, step = 10000, running loss = 0.8430
# val accuracy: 62.66, avg loss = 1.103
# epoch 35, step = 01000, running loss = 0.7499
# epoch 35, step = 02000, running loss = 0.7868
# epoch 35, step = 03000, running loss = 0.7803
# epoch 35, step = 04000, running loss = 0.7948
# epoch 35, step = 05000, running loss = 0.7914
# epoch 35, step = 06000, running loss = 0.7855
# epoch 35, step = 07000, running loss = 0.7636
# epoch 35, step = 08000, running loss = 0.7807
# epoch 35, step = 09000, running loss = 0.7898
# epoch 35, step = 10000, running loss = 0.7903
# val accuracy: 62.52, avg loss = 1.109
# epoch 36, step = 01000, running loss = 0.7270
# epoch 36, step = 02000, running loss = 0.7633
# epoch 36, step = 03000, running loss = 0.7819
# epoch 36, step = 04000, running loss = 0.7482
# epoch 36, step = 05000, running loss = 0.7648
# epoch 36, step = 06000, running loss = 0.7794
# epoch 36, step = 07000, running loss = 0.7806
# epoch 36, step = 08000, running loss = 0.7982
# epoch 36, step = 09000, running loss = 0.7909
# epoch 36, step = 10000, running loss = 0.7870
# val accuracy: 61.44, avg loss = 1.140
# epoch 37, step = 01000, running loss = 0.7429
# epoch 37, step = 02000, running loss = 0.7504
# epoch 37, step = 03000, running loss = 0.7711
# epoch 37, step = 04000, running loss = 0.7663
# epoch 37, step = 05000, running loss = 0.7318
# epoch 37, step = 06000, running loss = 0.7275
# epoch 37, step = 07000, running loss = 0.7978
# epoch 37, step = 08000, running loss = 0.7561
# epoch 37, step = 09000, running loss = 0.7693
# epoch 37, step = 10000, running loss = 0.7857
# val accuracy: 62.84, avg loss = 1.100
# epoch 38, step = 01000, running loss = 0.7244
# epoch 38, step = 02000, running loss = 0.7380
# epoch 38, step = 03000, running loss = 0.7388
# epoch 38, step = 04000, running loss = 0.7576
# epoch 38, step = 05000, running loss = 0.7723
# epoch 38, step = 06000, running loss = 0.7758
# epoch 38, step = 07000, running loss = 0.7461
# epoch 38, step = 08000, running loss = 0.7343
# epoch 38, step = 09000, running loss = 0.7583
# epoch 38, step = 10000, running loss = 0.7738
# val accuracy: 62.05, avg loss = 1.123
# epoch 39, step = 01000, running loss = 0.7316
# epoch 39, step = 02000, running loss = 0.7436
# epoch 39, step = 03000, running loss = 0.7195
# epoch 39, step = 04000, running loss = 0.7192
# epoch 39, step = 05000, running loss = 0.7667
# epoch 39, step = 06000, running loss = 0.7687
# epoch 39, step = 07000, running loss = 0.7589
# epoch 39, step = 08000, running loss = 0.7527
# epoch 39, step = 09000, running loss = 0.7399
# epoch 39, step = 10000, running loss = 0.7339
# val accuracy: 62.60, avg loss = 1.124
# epoch 40, step = 01000, running loss = 0.6777
# epoch 40, step = 02000, running loss = 0.7473
# epoch 40, step = 03000, running loss = 0.7339
# epoch 40, step = 04000, running loss = 0.7415
# epoch 40, step = 05000, running loss = 0.7291
# epoch 40, step = 06000, running loss = 0.7232
# epoch 40, step = 07000, running loss = 0.7565
# epoch 40, step = 08000, running loss = 0.7342
# epoch 40, step = 09000, running loss = 0.7402
# epoch 40, step = 10000, running loss = 0.7508
# val accuracy: 61.67, avg loss = 1.147
# epoch 41, step = 01000, running loss = 0.6864
# epoch 41, step = 02000, running loss = 0.7452
# epoch 41, step = 03000, running loss = 0.7049
# epoch 41, step = 04000, running loss = 0.7055
# epoch 41, step = 05000, running loss = 0.7433
# epoch 41, step = 06000, running loss = 0.7281
# epoch 41, step = 07000, running loss = 0.7161
# epoch 41, step = 08000, running loss = 0.7330
# epoch 41, step = 09000, running loss = 0.7345
# epoch 41, step = 10000, running loss = 0.7481
# val accuracy: 62.62, avg loss = 1.134
# epoch 42, step = 01000, running loss = 0.6789
# epoch 42, step = 02000, running loss = 0.7119
# epoch 42, step = 03000, running loss = 0.6983
# epoch 42, step = 04000, running loss = 0.7272
# epoch 42, step = 05000, running loss = 0.7261
# epoch 42, step = 06000, running loss = 0.7205
# epoch 42, step = 07000, running loss = 0.7579
# epoch 42, step = 08000, running loss = 0.7225
# epoch 42, step = 09000, running loss = 0.7147
# epoch 42, step = 10000, running loss = 0.7209
# val accuracy: 62.23, avg loss = 1.146
# epoch 43, step = 01000, running loss = 0.6999
# epoch 43, step = 02000, running loss = 0.6990
# epoch 43, step = 03000, running loss = 0.6714
# epoch 43, step = 04000, running loss = 0.7072
# epoch 43, step = 05000, running loss = 0.6836
# epoch 43, step = 06000, running loss = 0.7310
# epoch 43, step = 07000, running loss = 0.7106
# epoch 43, step = 08000, running loss = 0.7136
# epoch 43, step = 09000, running loss = 0.7180
# epoch 43, step = 10000, running loss = 0.7367
# val accuracy: 62.34, avg loss = 1.156
# epoch 44, step = 01000, running loss = 0.6498
# epoch 44, step = 02000, running loss = 0.6747
# epoch 44, step = 03000, running loss = 0.6928
# epoch 44, step = 04000, running loss = 0.6828
# epoch 44, step = 05000, running loss = 0.7059
# epoch 44, step = 06000, running loss = 0.7051
# epoch 44, step = 07000, running loss = 0.7069
# epoch 44, step = 08000, running loss = 0.7293
# epoch 44, step = 09000, running loss = 0.7133
# epoch 44, step = 10000, running loss = 0.7321
# val accuracy: 61.90, avg loss = 1.156
# epoch 45, step = 01000, running loss = 0.6656
# epoch 45, step = 02000, running loss = 0.6685
# epoch 45, step = 03000, running loss = 0.6820
# epoch 45, step = 04000, running loss = 0.6968
# epoch 45, step = 05000, running loss = 0.6871
# epoch 45, step = 06000, running loss = 0.7104
# epoch 45, step = 07000, running loss = 0.6776
# epoch 45, step = 08000, running loss = 0.7016
# epoch 45, step = 09000, running loss = 0.7175
# epoch 45, step = 10000, running loss = 0.7046
# val accuracy: 62.71, avg loss = 1.158
# epoch 46, step = 01000, running loss = 0.6577
# epoch 46, step = 02000, running loss = 0.6742
# epoch 46, step = 03000, running loss = 0.6606
# epoch 46, step = 04000, running loss = 0.6751
# epoch 46, step = 05000, running loss = 0.6832
# epoch 46, step = 06000, running loss = 0.6927
# epoch 46, step = 07000, running loss = 0.6874
# epoch 46, step = 08000, running loss = 0.7033
# epoch 46, step = 09000, running loss = 0.7310
# epoch 46, step = 10000, running loss = 0.6773
# val accuracy: 61.78, avg loss = 1.181
# epoch 47, step = 01000, running loss = 0.6827
# epoch 47, step = 02000, running loss = 0.6571
# epoch 47, step = 03000, running loss = 0.6738
# epoch 47, step = 04000, running loss = 0.6496
# epoch 47, step = 05000, running loss = 0.7001
# epoch 47, step = 06000, running loss = 0.6681
# epoch 47, step = 07000, running loss = 0.7073
# epoch 47, step = 08000, running loss = 0.6611
# epoch 47, step = 09000, running loss = 0.6685
# epoch 47, step = 10000, running loss = 0.6671
# val accuracy: 62.18, avg loss = 1.176
# epoch 48, step = 01000, running loss = 0.6230
# epoch 48, step = 02000, running loss = 0.6276
# epoch 48, step = 03000, running loss = 0.6678
# epoch 48, step = 04000, running loss = 0.6622
# epoch 48, step = 05000, running loss = 0.6663
# epoch 48, step = 06000, running loss = 0.6629
# epoch 48, step = 07000, running loss = 0.6944
# epoch 48, step = 08000, running loss = 0.6730
# epoch 48, step = 09000, running loss = 0.6954
# epoch 48, step = 10000, running loss = 0.6896
# val accuracy: 61.62, avg loss = 1.193
# epoch 49, step = 01000, running loss = 0.6341
# epoch 49, step = 02000, running loss = 0.6298
# epoch 49, step = 03000, running loss = 0.6440
# epoch 49, step = 04000, running loss = 0.6705
# epoch 49, step = 05000, running loss = 0.6488
# epoch 49, step = 06000, running loss = 0.6534
# epoch 49, step = 07000, running loss = 0.6770
# epoch 49, step = 08000, running loss = 0.6680
# epoch 49, step = 09000, running loss = 0.6720
# epoch 49, step = 10000, running loss = 0.6707
# val accuracy: 61.84, avg loss = 1.205

# %% [markdown]
# Testing
#
# The other things to do is to calculate the [confusion matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) to see the accuracy of individual classes.

# %%
from os import access
total_correct_pred = 0

for i, batch in enumerate(testloader):
  inputs, labels = batch
  inputs = inputs.to(device)
  labels = labels.to(device)

  curr_correct_pred, _ = val_step(model, inputs, labels)

  # adding up correctly predicted samples
  total_correct_pred += curr_correct_pred

# total accuracy
acc = total_correct_pred / len(testloader.dataset)
print("testing accuracy: {:.2f}%".format(100*acc))
# Out:
# testing accuracy: 61.88%
